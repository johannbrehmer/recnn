# %%
import sys
import numpy as np
import pickle
import h5py
import bz2
from numpy.random import poisson
import math
import re
from rootpy.vector import LorentzVector
# Out:
# Welcome to JupyROOT 6.10/06

# %% [markdown]
# # Convert pileup ascii to numpy

# %%
def dat2arrays(filenames_in, filename_out):  
    number = r"[+\-]?(?:0|[1-9]\d*)(?:\.\d*)?(?:[eE][+\-]?\d+)?"
    vector = r"\[(%s),(%s),(%s),(%s)\]" % (number, number, number, number)
    
    n_events = 0
    n_particles = 0
    
    with bz2.BZ2File(filename_out, "w") as output_file:
        for filename in filenames_in:
            with open(filename, "r") as f:
                for line in f:
                    if line.startswith("HADS: "):
                        n_events += 1
                        e = []
                        for p in re.findall(vector, line):
                            n_particles += 1
                            
                            # Option 1
                            v = LorentzVector()
                            v.set_pt_eta_phi_e(float(p[0]), float(p[1]), float(p[2]), float(p[3]))
                            e.append([v.px, v.py, v.pz, v.e])
                            
                            # Option 2 (old)
                            #e.append([float(p[0]), float(p[1]), float(p[2]), float(p[3])])
                    
                        e = np.array(e, dtype=np.float16)
                        pickle.dump(e, output_file, protocol=2)

                        if n_events % 10000 == 0:
                            print(n_events, 'events with mean of', n_particles / n_events, 'particles done')

# %%
# Go!
folder = '/scratch/jb6504/data'
#folder = '../data'

filenames_in = [folder + '/pileup/pileup' + str(i) + '_ascii.dat' for i in range(1,5)]
filename_out = folder + '/pileup/pileup_new.dat.tar.bz2'

dat2arrays(filenames_in, filename_out)
# Out:
# 10000 events with mean of 188.3852 particles done
# 20000 events with mean of 187.86085 particles done
# 30000 events with mean of 187.37263333333334 particles done
# 40000 events with mean of 187.707475 particles done
# 50000 events with mean of 187.99068 particles done
# 60000 events with mean of 188.43116666666666 particles done
# 70000 events with mean of 188.40937142857143 particles done
# 80000 events with mean of 188.451175 particles done
# 90000 events with mean of 188.34774444444446 particles done
# 100000 events with mean of 188.08741 particles done
# 110000 events with mean of 188.0740181818182 particles done
# 120000 events with mean of 188.13656666666665 particles done
# 130000 events with mean of 188.25896153846153 particles done
# 140000 events with mean of 188.22232142857143 particles done
# 150000 events with mean of 188.30068666666668 particles done
# 160000 events with mean of 188.13825625 particles done
# 170000 events with mean of 188.04893529411765 particles done
# 180000 events with mean of 188.1776 particles done
# 190000 events with mean of 188.1117 particles done
# 200000 events with mean of 188.22387 particles done
# 210000 events with mean of 188.2011380952381 particles done
# 220000 events with mean of 188.13805909090908 particles done
# 230000 events with mean of 188.1187304347826 particles done
# 240000 events with mean of 188.2041625 particles done
# 250000 events with mean of 188.28336 particles done
# 260000 events with mean of 188.24070384615385 particles done
# 270000 events with mean of 188.25076296296297 particles done
# 280000 events with mean of 188.2076142857143 particles done
# 290000 events with mean of 188.21641379310344 particles done
# 300000 events with mean of 188.25482666666667 particles done
# 310000 events with mean of 188.2167806451613 particles done
# 320000 events with mean of 188.173015625 particles done
# 330000 events with mean of 188.19961818181818 particles done
# 340000 events with mean of 188.1748588235294 particles done
# 350000 events with mean of 188.28016285714287 particles done
# 360000 events with mean of 188.33022222222223 particles done
# 370000 events with mean of 188.24024324324324 particles done
# 380000 events with mean of 188.19776842105264 particles done
# 390000 events with mean of 188.1777846153846 particles done
# 400000 events with mean of 188.2266975 particles done
# 410000 events with mean of 188.2017268292683 particles done
# 420000 events with mean of 188.18940476190477 particles done
# 430000 events with mean of 188.1649558139535 particles done
# 440000 events with mean of 188.17933863636364 particles done
# 450000 events with mean of 188.1374911111111 particles done
# 460000 events with mean of 188.16199130434782 particles done
# 470000 events with mean of 188.05428936170213 particles done
# 480000 events with mean of 188.07335208333333 particles done
# 490000 events with mean of 188.05878163265305 particles done
# 500000 events with mean of 188.041418 particles done
# 510000 events with mean of 188.05776274509805 particles done
# 520000 events with mean of 188.0825576923077 particles done
# 530000 events with mean of 188.0958283018868 particles done
# 540000 events with mean of 188.0819148148148 particles done
# 550000 events with mean of 188.1041181818182 particles done
# 560000 events with mean of 188.10173214285714 particles done
# 570000 events with mean of 188.07966666666667 particles done
# 580000 events with mean of 188.0638448275862 particles done
# 590000 events with mean of 188.0648745762712 particles done
# 600000 events with mean of 188.09467833333332 particles done
# 610000 events with mean of 188.10164918032788 particles done
# 620000 events with mean of 188.08219032258066 particles done
# 630000 events with mean of 188.10890952380953 particles done
# 640000 events with mean of 188.10801875 particles done
# 650000 events with mean of 188.10733076923077 particles done
# 660000 events with mean of 188.07213333333334 particles done
# 670000 events with mean of 188.0738 particles done
# 680000 events with mean of 188.0587705882353 particles done
# 690000 events with mean of 188.03039855072464 particles done
# 700000 events with mean of 188.0464042857143 particles done
# 710000 events with mean of 188.0547394366197 particles done
# 720000 events with mean of 188.0769388888889 particles done
# 730000 events with mean of 188.0983301369863 particles done
# 740000 events with mean of 188.06953243243242 particles done
# 750000 events with mean of 188.10768533333334 particles done
# 760000 events with mean of 188.11307236842106 particles done
# 770000 events with mean of 188.12126103896105 particles done
# 780000 events with mean of 188.10934615384616 particles done
# 790000 events with mean of 188.0932329113924 particles done
# 800000 events with mean of 188.06641375 particles done
# 810000 events with mean of 188.04626666666667 particles done
# 820000 events with mean of 188.03851707317074 particles done
# 830000 events with mean of 188.0614530120482 particles done
# 840000 events with mean of 188.09585833333333 particles done
# 850000 events with mean of 188.08563294117647 particles done
# 860000 events with mean of 188.0932 particles done
# 870000 events with mean of 188.08588045977012 particles done
# 880000 events with mean of 188.0725840909091 particles done
# 890000 events with mean of 188.06750786516855 particles done
# 900000 events with mean of 188.03190777777777 particles done
# 910000 events with mean of 188.0297967032967 particles done
# 920000 events with mean of 188.02738260869566 particles done
# 930000 events with mean of 188.03004731182796 particles done
# 940000 events with mean of 188.00369893617022 particles done
# 950000 events with mean of 188.00310947368422 particles done
# 960000 events with mean of 188.0079625 particles done
# 970000 events with mean of 188.04294845360826 particles done
# 980000 events with mean of 188.0296244897959 particles done
# 990000 events with mean of 188.01510404040405 particles done
# 1000000 events with mean of 188.025502 particles done
# 1010000 events with mean of 188.03730396039603 particles done
# 1020000 events with mean of 188.03931078431373 particles done
# 1030000 events with mean of 188.06208155339806 particles done
# 1040000 events with mean of 188.06011057692308 particles done
# 1050000 events with mean of 188.06554571428572 particles done
# 1060000 events with mean of 188.08190660377358 particles done
# 1070000 events with mean of 188.07389626168225 particles done
# 1080000 events with mean of 188.03722037037036 particles done
# 1090000 events with mean of 188.0271027522936 particles done
# 1100000 events with mean of 188.01222272727273 particles done
# 1110000 events with mean of 188.0047135135135 particles done
# 1120000 events with mean of 188.00928303571428 particles done
# 1130000 events with mean of 188.00368407079645 particles done
# 1140000 events with mean of 188.01798596491227 particles done
# 1150000 events with mean of 188.03504869565216 particles done
# 1160000 events with mean of 188.04921551724138 particles done
# 1170000 events with mean of 188.04452905982907 particles done
# 1180000 events with mean of 188.06526271186442 particles done
# 1190000 events with mean of 188.08168655462185 particles done
# 1200000 events with mean of 188.07342333333332 particles done
# 1210000 events with mean of 188.075252892562 particles done
# 1220000 events with mean of 188.08685655737705 particles done
# 1230000 events with mean of 188.07629512195123 particles done
# 1240000 events with mean of 188.08891048387096 particles done
# 1250000 events with mean of 188.103888 particles done
# 1260000 events with mean of 188.0966261904762 particles done
# 1270000 events with mean of 188.09748267716535 particles done
# 1280000 events with mean of 188.09025703125 particles done
# 1290000 events with mean of 188.0843449612403 particles done
# 1300000 events with mean of 188.0851876923077 particles done
# 1310000 events with mean of 188.091520610687 particles done
# 1320000 events with mean of 188.0745106060606 particles done
# 1330000 events with mean of 188.08693684210527 particles done
# 1340000 events with mean of 188.10721641791045 particles done
# 1350000 events with mean of 188.12717407407408 particles done
# 1360000 events with mean of 188.13094264705882 particles done
# 1370000 events with mean of 188.15006569343066 particles done
# 1380000 events with mean of 188.13782246376812 particles done
# 1390000 events with mean of 188.13382230215828 particles done
# 1400000 events with mean of 188.14370857142856 particles done
# 1410000 events with mean of 188.1478375886525 particles done
# 1420000 events with mean of 188.15533309859154 particles done
# 1430000 events with mean of 188.1383132867133 particles done
# 1440000 events with mean of 188.12727083333334 particles done
# 1450000 events with mean of 188.12042689655172 particles done
# 1460000 events with mean of 188.12135410958905 particles done
# 1470000 events with mean of 188.1106448979592 particles done
# 1480000 events with mean of 188.114275 particles done
# 1490000 events with mean of 188.1282932885906 particles done
# 1500000 events with mean of 188.11858266666667 particles done
# 1510000 events with mean of 188.1213715231788 particles done
# 1520000 events with mean of 188.12452565789474 particles done
# 1530000 events with mean of 188.11845490196077 particles done
# 1540000 events with mean of 188.10463116883116 particles done
# 1550000 events with mean of 188.11108580645163 particles done
# 1560000 events with mean of 188.08961025641025 particles done
# 1570000 events with mean of 188.09696369426752 particles done
# 1580000 events with mean of 188.09494556962025 particles done
# 1590000 events with mean of 188.1003647798742 particles done
# 1600000 events with mean of 188.111008125 particles done
# 1610000 events with mean of 188.102700621118 particles done
# 1620000 events with mean of 188.1052549382716 particles done
# 1630000 events with mean of 188.1073153374233 particles done
# 1640000 events with mean of 188.10605243902438 particles done
# 1650000 events with mean of 188.11418787878787 particles done
# 1660000 events with mean of 188.1132060240964 particles done
# 1670000 events with mean of 188.12036946107784 particles done
# 1680000 events with mean of 188.11765357142858 particles done
# 1690000 events with mean of 188.09570591715976 particles done
# 1700000 events with mean of 188.084 particles done
# 1710000 events with mean of 188.0720461988304 particles done
# 1720000 events with mean of 188.07480872093024 particles done
# 1730000 events with mean of 188.07127630057803 particles done
# 1740000 events with mean of 188.06479425287355 particles done
# 1750000 events with mean of 188.06116 particles done
# 1760000 events with mean of 188.05836647727273 particles done
# 1770000 events with mean of 188.0706186440678 particles done
# 1780000 events with mean of 188.0640129213483 particles done
# 1790000 events with mean of 188.06325530726258 particles done
# 1800000 events with mean of 188.05704666666668 particles done
# 1810000 events with mean of 188.06735745856355 particles done
# 1820000 events with mean of 188.0798565934066 particles done
# 1830000 events with mean of 188.0838519125683 particles done
# 1840000 events with mean of 188.08251630434782 particles done
# 1850000 events with mean of 188.0910718918919 particles done
# 1860000 events with mean of 188.09693494623656 particles done
# 1870000 events with mean of 188.09552459893047 particles done
# 1880000 events with mean of 188.0790085106383 particles done
# 1890000 events with mean of 188.09851693121692 particles done
# 1900000 events with mean of 188.10730052631578 particles done
# 1910000 events with mean of 188.1050617801047 particles done
# 1920000 events with mean of 188.09111666666666 particles done
# 1930000 events with mean of 188.08900829015545 particles done
# 1940000 events with mean of 188.0919850515464 particles done
# 1950000 events with mean of 188.1013353846154 particles done
# 1960000 events with mean of 188.10528979591837 particles done
# 1970000 events with mean of 188.10500253807106 particles done
# 1980000 events with mean of 188.10308787878787 particles done
# 1990000 events with mean of 188.10534120603015 particles done
# 2000000 events with mean of 188.101586 particles done

# %% [markdown]
# # Jets, particle level

# %%
def add_pileup_jet_particle(hard_filename, output_filename,
                            pileup_file, n_expected, use_poisson=True):
    
    ''' Adds pileup to a particle-level event file. '''

    print('')
    print('Adding pileup to ' + hard_filename + ' with pileup mean', n_expected)

    with h5py.File(hard_filename, 'r') as input_file:
        input_events = input_file['events']
        n_events_total = len(input_events)

        with h5py.File(output_filename, 'w') as output_file:
            dt_momentum = np.dtype([('E', np.float16), ('px', np.float16), ('py', np.float16), ('pz', np.float16)])
            #dt_event = h5py.special_dtype(vlen='float32, float32, float32, float32')
            dt_event = h5py.special_dtype(vlen=dt_momentum)
            output_events = output_file.create_dataset('events', (n_events_total,), dtype=dt_event)

            total_hard_particles = 0
            total_pileup_particles = 0
            n_events = 0
            
            #pileup_energies = []
            #hard_energies = []

            for event in input_events:
                
                # Get hard momenta
                n_momenta = len(event)
                momenta = np.zeros((n_momenta,), dtype = dt_momentum)
                for i, p in enumerate(event):
                    momenta[i] = (p[0], p[1], p[2], p[3])
                    #hard_energies.append((p[1]**2 + p[2]**2)**0.5)
                total_hard_particles += n_momenta

                # Calculate amount of pileup
                if use_poisson:
                    n_pileup = poisson(n_expected)
                else:
                    n_pileup = n_expected

                # Get pileup momenta
                pileup_momenta_raw = []
                for i in range(n_pileup):
                    try:
                        pileup_momenta_raw += list(pickle.load(pileup_file, encoding='latin1'))
                    except EOFError:
                        # At end of file, rewind
                        pileup_file.seek(0)
                        pileup_momenta_raw += list(pickle.load(pileup_file, encoding='latin1'))
                        print('Starting from beginning of pileup file.')
                n_pileup_particles = len(pileup_momenta_raw)
                pileup_momenta = np.zeros((n_pileup_particles,), dtype = dt_momentum)
                for i, p in enumerate(pileup_momenta_raw):
                    pileup_momenta[i] = (p[3], p[0], p[1], p[2])
                    #pileup_energies.append((p[0]**2 + p[1]**2)**0.5)
                total_pileup_particles += n_pileup_particles

                if len(pileup_momenta) > 0:
                    momenta = np.hstack((momenta, pileup_momenta))
                    
                output_events[n_events] = momenta
                n_events += 1

                if n_events % 1000 == 0:
                    print(' ', n_events, 'events done, mean particles:',
                          total_hard_particles / n_events, '+', total_pileup_particles / n_events)

    print('Summary:')
    print('  Events:', n_events)
    print('  Average hard particles:', total_hard_particles / n_events)
    print('  Average pileup particles:', total_pileup_particles / n_events)
    #print('  Average hard pT:', np.mean(hard_energies))
    #print('  Average pileup pT:', np.mean(pileup_energies))

# %%
# Go!
folder = '/scratch/jb6504/data'
#folder = '../data'
hard_filenames = [folder + '/w-vs-qcd/h5/w_100000.h5',
                  folder + '/w-vs-qcd/h5/qcd_100000.h5']
n_expected = [25,
              25]
output_filenames = [folder + '/w-vs-qcd/h5/w_100000_pileup25_new.h5',
                    folder + '/w-vs-qcd/h5/qcd_100000_pileup25_new.h5']
pileup_filename = folder + '/pileup/pileup_new.dat.tar.bz2'

pileup_file = bz2.BZ2File(pileup_filename, "r")

for hard_filename, n, output_filename in zip(hard_filenames, n_expected, output_filenames):
    add_pileup_jet_particle(hard_filename, output_filename, pileup_file, n, True)
# Out:
# Adding pileup to /scratch/jb6504/data/w-vs-qcd/h5/w_100000.h5 with pileup mean 25
#   1000 events done, mean particles: 428.348 + 4719.152
#   2000 events done, mean particles: 432.2455 + 4695.489
#   3000 events done, mean particles: 431.94233333333335 + 4683.953333333333
#   4000 events done, mean particles: 431.92525 + 4689.99525
#   5000 events done, mean particles: 431.0316 + 4699.7112
#   6000 events done, mean particles: 431.747 + 4695.606833333333
#   7000 events done, mean particles: 430.9875714285714 + 4696.590571428572
#   8000 events done, mean particles: 431.394875 + 4702.621375
#   9000 events done, mean particles: 431.69244444444445 + 4700.183666666667
#   10000 events done, mean particles: 432.233 + 4702.4462
#   11000 events done, mean particles: 433.0108181818182 + 4699.714454545455
#   12000 events done, mean particles: 433.652 + 4698.211166666667
#   13000 events done, mean particles: 433.865 + 4699.861769230769
#   14000 events done, mean particles: 433.34264285714283 + 4703.6675
#   15000 events done, mean particles: 433.16313333333335 + 4701.673666666667
#   16000 events done, mean particles: 432.7071875 + 4700.702
#   17000 events done, mean particles: 432.1235294117647 + 4699.477117647059
#   18000 events done, mean particles: 431.76522222222223 + 4698.004055555555
#   59000 events done, mean particles: 532.7628474576271 + 4698.777288135593
# Starting from beginning of pileup file.
#   60000 events done, mean particles: 532.8415666666667 + 4698.923666666667
#   61000 events done, mean particles: 532.9550163934426 + 4698.235721311476
#   62000 events done, mean particles: 532.8604677419355 + 4697.7020483870965
#   63000 events done, mean particles: 532.6968253968254 + 4697.941492063492
#   64000 events done, mean particles: 532.8190625 + 4697.7159375
#   65000 events done, mean particles: 532.9527692307693 + 4698.3778923076925
#   66000 events done, mean particles: 532.9865606060606 + 4698.885075757576
#   67000 events done, mean particles: 533.0448656716418 + 4698.862776119403
#   68000 events done, mean particles: 533.1234264705882 + 4700.123838235294
#   69000 events done, mean particles: 533.2378260869565 + 4700.870304347826
#   70000 events done, mean particles: 533.1916142857143 + 4701.8509
#   71000 events done, mean particles: 533.3341408450705 + 4701.218549295774
#   72000 events done, mean particles: 533.3167916666666 + 4701.339027777778
#   73000 events done, mean particles: 533.2829863013699 + 4700.758506849315
#   74000 events done, mean particles: 533.3016756756757 + 4700.982135135135
#   75000 events done, mean particles: 533.2746 + 4700.959386666666
#   76000 events done, mean particles: 533.2320394736843 + 4701.75472368421
#   77000 events done, mean particles: 533.2083896103896 + 4701.975909090909
#   78000 events done, mean particles: 533.1879743589743 + 4701.760102564102
#   79000 events done, mean particles: 533.1792531645569 + 4701.34853164557
#   80000 events done, mean particles: 533.0773125 + 4701.764075
#   81000 events done, mean particles: 533.0412839506173 + 4702.24675308642
#   82000 events done, mean particles: 533.099 + 4702.449902439024
#   83000 events done, mean particles: 532.9463975903615 + 4701.589734939759
#   84000 events done, mean particles: 532.948369047619 + 4702.291226190476
#   85000 events done, mean particles: 532.8682823529412 + 4702.574047058823
#   86000 events done, mean particles: 532.8877441860465 + 4702.100418604651
#   87000 events done, mean particles: 532.8302298850575 + 4701.5004022988505
#   88000 events done, mean particles: 532.8273863636364 + 4701.490329545454
#   89000 events done, mean particles: 532.7178764044944 + 4701.672494382023
#   90000 events done, mean particles: 532.7471333333333 + 4701.806455555556
#   91000 events done, mean particles: 532.6744615384615 + 4701.942274725275
#   92000 events done, mean particles: 532.6767826086957 + 4701.289815217391
#   93000 events done, mean particles: 532.7407741935484 + 4700.806322580645
#   94000 events done, mean particles: 532.8601808510638 + 4701.496053191489
#   95000 events done, mean particles: 532.8551789473685 + 4701.947968421053
#   96000 events done, mean particles: 532.8530208333333 + 4700.877260416667
#   97000 events done, mean particles: 532.9023402061856 + 4700.8238556701035
#   98000 events done, mean particles: 532.9711020408163 + 4700.261459183674
#   99000 events done, mean particles: 532.9742424242424 + 4700.757696969697
#   100000 events done, mean particles: 532.97085 + 4700.32407
# Summary:
#   Events: 100000
#   Average hard particles: 532.97085
#   Average pileup particles: 4700.32407

# %% [markdown]
# # Full event, particle level

# %%
def add_pileup_event_particle(hard_filename, output_filename,
                              pileup_file, n_expected, use_poisson=True):
    
    ''' Adds pileup to a particle-level event file. '''

    print('')
    print('Adding pileup to ' + hard_filename + ' with pileup mean', n_expected)

    with open(hard_filename, 'rb') as input_file:
    #with bz2.BZ2File(hard_filename, "r") as input_file:
        with bz2.BZ2File(output_filename, "w") as output_file:
            
            total_hard_particles = 0
            total_pileup_particles = 0
            n_events = 0

            while True:
                try:
                    momenta = pickle.load(input_file, encoding='latin1')
                except EOFError:
                    break
                n_events += 1
                total_hard_particles += len(momenta)
                
                if use_poisson:
                    n_pileup = poisson(n_expected)
                else:
                    n_pileup = n_expected
                
                pileup_momenta = []
                for i in range(n_pileup):
                    try:
                        pileup_momenta += list(pickle.load(pileup_file, encoding='latin1'))
                    except EOFError:
                        # At end of file, rewind
                        pileup_file.seek(0)
                        pileup_momenta += list(pickle.load(pileup_file, encoding='latin1'))
                        print('Starting from beginning of pileup file.')
                total_pileup_particles += len(pileup_momenta)
                pileup_momenta = np.asarray(pileup_momenta)
                
                if len(pileup_momenta) > 0:
                    momenta = np.vstack((momenta, pileup_momenta))
                pickle.dump(momenta, output_file)

                if n_events % 10000 == 0:
                    print(' ', n_events, 'events done, mean particles:',
                          total_hard_particles / n_events, '+', total_pileup_particles / n_events)

    print('Summary:')
    print('  Events:', n_events)
    print('  Average hard particles:', total_hard_particles / n_events)
    print('  Average pileup particles:', total_pileup_particles / n_events)

# %%
# Go!
folder = '/scratch/jb6504/data'
#folder = '../data'
hard_filenames = [folder + '/events/wprime-particles.dat',
                  folder + '/events/dijet-particles.dat']
n_expected = [25,
              25]
output_filenames = [folder + '/events/wprime-particles-pileup25.dat.bz2',
                    folder + '/events/dijet-particles-pileup25.dat.bz2']
pileup_filename = folder + '/pileup/pileup.dat.bz2'

#pileup_file = open(pileup_filename, 'rb') 
pileup_file = bz2.BZ2File(pileup_filename, "r")

for hard_filename, n, output_filename in zip(hard_filenames, n_expected, output_filenames):
    add_pileup_event_particle(hard_filename, output_filename, pileup_file, n, True)
# Out:
# Adding pileup to /scratch/jb6504/data/events/dijet-particles.dat with pileup mean 25
#   10000 events done, mean particles: 530.4376 + 4699.4621
#   20000 events done, mean particles: 531.0632 + 4694.9929
#   30000 events done, mean particles: 530.9473333333333 + 4699.0671
#   40000 events done, mean particles: 531.29085 + 4692.46765
#   50000 events done, mean particles: 531.02312 + 4696.99316
#   60000 events done, mean particles: 530.807 + 4699.600416666667
#   70000 events done, mean particles: 530.9862857142857 + 4699.089557142857
# Starting from beginning of pileup file.
#   80000 events done, mean particles: 530.9101375 + 4702.6208375
#   90000 events done, mean particles: 530.8895 + 4705.0044333333335
#   100000 events done, mean particles: 530.96907 + 4704.84843
#   110000 events done, mean particles: 531.0724181818182 + 4704.951145454545
#   120000 events done, mean particles: 530.7914166666667 + 4704.724333333334
#   130000 events done, mean particles: 530.7209769230769 + 4705.773946153846
#   140000 events done, mean particles: 530.8185357142858 + 4707.4673
#   150000 events done, mean particles: 530.6589933333333 + 4706.732106666666
# Starting from beginning of pileup file.
#   160000 events done, mean particles: 530.5087375 + 4706.742425
#   170000 events done, mean particles: 530.4688764705883 + 4707.042911764706
#   180000 events done, mean particles: 530.4218944444444 + 4706.947977777778
#   190000 events done, mean particles: 530.1930736842105 + 4707.058431578947
#   200000 events done, mean particles: 530.17936 + 4706.703065
#   210000 events done, mean particles: 530.1623571428571 + 4707.1885
#   220000 events done, mean particles: 530.1784363636364 + 4706.991263636363
#   230000 events done, mean particles: 530.2003347826087 + 4706.8523173913045
# Starting from beginning of pileup file.
#   240000 events done, mean particles: 530.1742791666667 + 4706.733325
#   250000 events done, mean particles: 530.16182 + 4706.83388
#   260000 events done, mean particles: 530.1169346153846 + 4706.006823076923
#   270000 events done, mean particles: 530.1674111111112 + 4705.812151851852
#   280000 events done, mean particles: 530.1426035714286 + 4705.736185714286
#   290000 events done, mean particles: 530.1175896551724 + 4706.095617241379
#   300000 events done, mean particles: 530.2048066666666 + 4706.087646666667
#   310000 events done, mean particles: 530.2146741935484 + 4705.299048387097
# Starting from beginning of pileup file.
#   320000 events done, mean particles: 530.357378125 + 4705.18265625
#   330000 events done, mean particles: 530.4098727272727 + 4705.565387878788
#   340000 events done, mean particles: 530.436255882353 + 4705.696944117647
#   350000 events done, mean particles: 530.3911942857143 + 4706.011105714286
#   360000 events done, mean particles: 530.3765222222222 + 4705.421030555555
#   370000 events done, mean particles: 530.4264648648649 + 4705.4379891891895
#   380000 events done, mean particles: 530.4858684210526 + 4705.046834210526
#   390000 events done, mean particles: 530.4429333333334 + 4704.3610461538465
# Starting from beginning of pileup file.
#   400000 events done, mean particles: 530.37957 + 4704.23617
#   410000 events done, mean particles: 530.5136219512195 + 4704.076256097561
#   420000 events done, mean particles: 530.5243095238095 + 4703.707180952381
#   430000 events done, mean particles: 530.5272186046511 + 4703.749525581396
#   440000 events done, mean particles: 530.4735931818182 + 4703.346179545454
#   450000 events done, mean particles: 530.4330511111111 + 4703.2650488888885
#   460000 events done, mean particles: 530.3657369565217 + 4703.692854347826
#   470000 events done, mean particles: 530.3936957446808 + 4703.718138297872
# Starting from beginning of pileup file.
#   480000 events done, mean particles: 530.4123854166667 + 4703.830814583333
#   490000 events done, mean particles: 530.3766755102041 + 4703.782224489796
#   500000 events done, mean particles: 530.346144 + 4703.804048
#   510000 events done, mean particles: 530.331774509804 + 4703.71031372549
#   520000 events done, mean particles: 530.4144 + 4703.517598076923
#   530000 events done, mean particles: 530.4060716981132 + 4703.5896
#   540000 events done, mean particles: 530.4492537037037 + 4703.709909259259
#   550000 events done, mean particles: 530.4809890909091 + 4703.617410909091
# Starting from beginning of pileup file.
#   560000 events done, mean particles: 530.5200482142857 + 4703.721776785715
#   570000 events done, mean particles: 530.4951561403509 + 4703.78156491228
#   580000 events done, mean particles: 530.5255913793103 + 4703.32621724138
#   590000 events done, mean particles: 530.4939508474577 + 4703.394461016949
#   600000 events done, mean particles: 530.526665 + 4703.033281666667
# Summary:
#   Events: 600000
#   Average hard particles: 530.526665
#   Average pileup particles: 4703.033281666667
